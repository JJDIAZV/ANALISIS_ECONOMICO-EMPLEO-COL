# %% [markdown]
# # ANÁLISIS ECONÓMICO:
# ## BENEFICIARIOS EMPLEO PARA LA PROSPERIDAD.
#
# El siguiente análisis contiene el conjunto de datos de los beneficiarios del programa Empleo para la prosperidad social, la base de datos es suministrada por la pag de "datos abiertos" del gobierno colombiano, la última actualización de la base corresponde al 26 de marzo de 2024, según fuente de prosperidad social.
#
#
# ### Retos:
# El reto principal consiste en realizar un análisis integral multidimensional de la base de datos para obtener una mejor comprensión de los beneficiarios de empleo para la prosperidad social y su impacto como proyecto del gobierno nacional; se requiere aplicar diversas técnicas de análisis de datos, incluyendo:
#
# 2.1. Análisis de Componentes Principales
#
# 2.2. Análisis de Conglomerados
#
# 2.3. Análisis de Correspondencia
#
# 2.4. Visualización de resultados
#
# El informe final debe incluir análisis detallados de los resultados obtenidos, las conclusiones clave y las recomendaciones específicas para guiar las decisiones estratégicas del departamento para la prosperidad social.  Se espera que este análisis de datos proporcione ventajas objetivas en el mercado laboral, optimizando las iniciativas y maximizando los beneficios de este proyecto social.
#
#
# ### Informe:
#
# Teniendo en cuenta la base de datos, se procede a presentar los diferentes análisis realizados a la misma, para poder brindar las mejores recomendaciones y conclusiones que le permitan establecer estrategias para su proceso.
#
# ### Información de la Entidad Gubernamental:
#
# Área o dependencia  :	Dirección de Inclusión Productiva
#
# Nombre de la Entidad:	Departamento Administrativo para la Prosperidad Social
#
# Departamento        :  	Bogotá D.C.
#
# Municipio           :   Bogotá D.C.
#
# Orden	            :   Nacional
#
# Sector	            :   Inclusión Social y Reconciliación
#
#
# ### Información de Datos:
#
#
# Idioma                     :	Español
#
# Cobertura Geográfica       :	Nacional
#
# Frecuencia de Actualización: 	Mensual
#
# Fecha Emisión (aaaa-mm-dd) :	2018-02-19
#
# URL Documentación	       : https://prosperidadsocial.gov.co/sgsp/gestion-y-articulacion-de-la-oferta-social/empleabilidad/
#
#
# Inicialmente, procedemos presentando la información de la base de datos:
#
# ## 0. Instalar librerías:

# %%
import pandas as pd
import numpy as np
import scipy as sp
import matplotlib.pyplot as plt

# %%
## cargar base de datos
Beneficiarios = pd.read_csv('Beneficiarios_Empleo_Para_La_Prosperidad_20240418.csv')

# %% [markdown]
# ## 1. Información de la base de datos:
#
#
# En el conjunto de datos existen 11.503 filas (Cada fila corresponde a una persona), adicional se describe 24 columnas con variables cualitativas y cuantitativas, como se observa a continuación:

# %%
print (Beneficiarios.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 11503 entries, 0 to 11502
# Data columns (total 24 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   CantidadDeBeneficiarios                 11503 non-null  int64
#  1   CantidadBeneficioConsolidado            11503 non-null  int64
#  2   CantidadUltimobeneficio                 11503 non-null  int64
#  3   CodigoDepartamentoAtencion              11503 non-null  int64
#  4   CodigoMunicipioAtencion                 11503 non-null  int64
#  5   CondicionSexual                         11503 non-null  object
#  6   Discapacidad                            11503 non-null  object
#  7   EstadoBeneficiario                      11503 non-null  object
#  8   EstadoCivil                             11503 non-null  object
#  9   Etnia                                   11503 non-null  object
# ...

# %%
# CVerificar si exiten datos NULL en la variables
print(Beneficiarios.shape)
Variables_NULL = Beneficiarios.isnull().sum()
print(Variables_NULL)
# Out:
# (11503, 24)
# CantidadDeBeneficiarios                   0
# CantidadBeneficioConsolidado              0
# CantidadUltimobeneficio                   0
# CodigoDepartamentoAtencion                0
# CodigoMunicipioAtencion                   0
# CondicionSexual                           0
# Discapacidad                              0
# EstadoBeneficiario                        0
# EstadoCivil                               0
# Etnia                                     0
# FechaInscripcionBeneficiario              0
# FechaUltimoBeneficioAsignado              0
# Genero                                    0
# NivelEscolaridad                          0
# NombreDepartamentoAtencion                0
# NombreMunicipioAtencion                   0
# Pais                                      0
# RangoEdad                                 0
# TipoAsignacionBeneficio                   0
# TipoBeneficio                             0
# TipoDocumento                             0
# ...

# %%
print(Beneficiarios.shape)
# Print the summary statistics of the numeric columns / data economic
summary_table_Beneficiarios= Beneficiarios.describe()
summary_table_Beneficiarios
# Out:
# (11503, 24)
#        CantidadDeBeneficiarios  CantidadBeneficioConsolidado  \
# count             11503.000000                  11503.000000
# mean                  1.851778                      3.577415
# std                   3.260368                      2.416270
# min                   1.000000                      1.000000
# 25%                   1.000000                      2.000000
# 50%                   1.000000                      3.000000
# 75%                   1.000000                      4.000000
# max                  77.000000                     15.000000
#
#        CantidadUltimobeneficio  CodigoDepartamentoAtencion  \
# count                  11503.0                11503.000000
# mean                       1.0                   25.114492
# std                        0.0                   23.684187
# min                        1.0                    5.000000
# 25%                        1.0                    8.000000
# ...

# %% [markdown]
# # En progreso:::::::::::::::::::::
